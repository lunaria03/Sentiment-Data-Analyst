# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.tokopedia.tkpd',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=2500, # defaults to 100
    filter_score_with=5 # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId               userName  \
# 0  a16f8708-c95f-419d-b998-ec56a9d0719b           Herry Potter
# 1  f11bdf9d-7c2b-4416-8c5b-59397f91a4d4    M Elang Kuncoro S N
# 2  ce8be2dc-938f-4473-957c-ae9ab942e349              Ratu Doll
# 3  a9a2cfdd-f928-46e9-9655-47352621e996        Muhammad Nashih
# 4  dede04cf-f573-41bb-93da-fb78e5795e78  Andi Suryawan Nugroho
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Dengan aplikasi ini belanja jadi lebih mudah t...      5              0
# 1  Sudah baik dan mudah digunakan hanya saja kura...      5              9
# ...

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 2500

# %%
df_busu[['at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#                    at                                            content
# 0 2023-11-23 17:56:15  Dengan aplikasi ini belanja jadi lebih mudah t...
# 1 2023-11-07 07:27:31  Sudah baik dan mudah digunakan hanya saja kura...
# 2 2023-11-07 16:49:24  Tokopedia sangat membantu saya untuk membeli b...
# 3 2023-11-09 14:36:01  E-Commerce Terbaik!!! saya sudah memggunaknnya...
# 4 2023-11-08 13:22:49  Sangat membantu utk berbelanja tanpa harus kel...

# %%
#Run This Code to Sort the Data By Date 

new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#                       userName  score                  at  \
# 491   Sahbani.putri @gmail.com      5 2023-11-24 22:49:47
# 1971           dampar sulistyo      5 2023-11-24 18:58:16
# 423               Riski Amelda      5 2023-11-24 18:44:53
# 296                 Kuro Black      5 2023-11-24 18:06:57
# 483            Nizam Romadhoni      5 2023-11-24 16:43:41
#
#                                                 content
# 491   Penanganan masalah nya lemot... Merugikan cost...
# 1971                             cepat & banyak potonga
# 423   optimal buat belanja Best respon dan rekomenda...
# 296   Alhamdulillah, respon cepat TOPED meyelesaikan...
# 483                     sangat memuaskan belanja di sni

# %%
my_df = df_busu[['at', 'content']] #get userName, rating, date-time, and reviews only

# %%
my_df.to_csv("tokpedpos.csv", index=False, sep=";")
